# %%
import numpy as np #导入NumPy数学工具箱
import pandas as pd #导入Pandas数据处理工具箱

# %%
df_bank = pd.read_csv('/content/drive/MyDrive/DL/data_test/handson_book/BankCustomer.csv')
df_bank.head() # 显示文件前5行
# Out:
#               Name  Gender  Age     City  Tenure  ProductsNo  HasCard  \
# 0         Kan Jian  Female   40  Beijing       9           2        0
# 1      Xue Baochai    Male   69  Beijing       6           2        0
# 2           Mao Xi  Female   32  Beijing       9           1        1
# 3  Zheng Nengliang  Female   37  Tianjin       0           2        1
# 4          Zhi Fen    Male   55  Tianjin       4           3        1
#
#    ActiveMember  Credit  AccountBal       Salary  Exited
# 0             1     516     6360.66       0.0000       0
# 1             1     682    28605.00       0.0000       0
# 2             1     803    10378.09  236311.0932       1
# 3             1     778    25564.01  129909.8079       1
# 4             0     547     3235.61  136976.1948       1

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          10000 non-null  object
#  1   Gender        10000 non-null  object
#  2   Age           10000 non-null  int64
#  3   City          10000 non-null  object
#  4   Tenure        10000 non-null  int64
#  5   ProductsNo    10000 non-null  int64
#  6   HasCard       10000 non-null  int64
#  7   ActiveMember  10000 non-null  int64
#  8   Credit        10000 non-null  int64
#  9   AccountBal    10000 non-null  float64
#  10  Salary        10000 non-null  float64
#  11  Exited        10000 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
import matplotlib.pyplot as plt #导入matplotlib画图工具箱
import seaborn as sns #导入seaborn画图工具箱
# 显示不同特征的分布情况
features=[ 'City', 'Gender','Age','Tenure',
           'ProductsNo', 'HasCard', 'ActiveMember', 'Exited']
fig=plt.subplots(figsize=(15,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = df_bank)
    plt.title("No. of costumers")
# Out:
# <ipython-input-4-71095c4e960b>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 2, i+1)

# %%
# 把二元类别文本数字化
df_bank['Gender'].replace("Female",0,inplace = True)
df_bank['Gender'].replace("Male",1,inplace=True)

# %%
# 显示数字类别
print("Gender unique values",df_bank['Gender'].unique())
# Out:
# Gender unique values [0 1]

# %%
# 把多元类别转换成多个二元哑变量，然后贴回原始数据集
d_city = pd.get_dummies(df_bank['City'], prefix = "City")
df_bank = [df_bank, d_city]
df_bank = pd.concat(df_bank, axis = 1)

# %%
y = df_bank ['Exited']
X = df_bank.drop(['Name', 'Exited','City'], axis=1)
X.head()
# Out:
#    Gender  Age  Tenure  ProductsNo  HasCard  ActiveMember  Credit  AccountBal  \
# 0       0   40       9           2        0             1     516     6360.66
# 1       1   69       6           2        0             1     682    28605.00
# 2       0   32       9           1        1             1     803    10378.09
# 3       0   37       0           2        1             1     778    25564.01
# 4       1   55       4           3        1             0     547     3235.61
#
#         Salary  City_Beijing  City_Shanghai  City_Tianjin
# 0       0.0000             1              0             0
# 1       0.0000             1              0             0
# 2  236311.0932             1              0             0
# 3  129909.8079             0              0             1
# 4  136976.1948             0              0             1

# %%
from sklearn.model_selection import train_test_split #拆分数据集
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                   test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler # 导入特征缩放器
sc = StandardScaler() # 特征缩放器
X_train = sc.fit_transform(X_train) # 拟合并应用于训练集
X_test = sc.transform (X_test) # 训练集结果应用于测试集

# %%
from sklearn.linear_model import LogisticRegression # 导入Sklearn模型
lr = LogisticRegression() # 逻辑回归模型
history = lr.fit(X_train,y_train) # 训练机器
print("逻辑回归测试集准确率 {:.2f}%".format(lr.score(X_test,y_test)*100))
# Out:
# 逻辑回归测试集准确率 80.50%

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=12, activation = 'relu'), #输入层
    tf.keras.layers.Dense(units=24, activation = 'relu'), #隐层
    tf.keras.layers.Dense(units=1, activation = 'sigmoid') #输出层，二分类
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
history = model.fit(X_train, y_train, # 指定训练集
                  epochs=100,        # 指定训练的轮次
                  batch_size=64,    # 指定数据批量
                  validation_data=(X_test, y_test)) #指定验证集,这里为了简化模型，直接用测试集数据进行验证
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5818: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 125/125 [==============================] - 4s 12ms/step - loss: 0.5624 - accuracy: 0.7206 - val_loss: 0.4797 - val_accuracy: 0.7915
# Epoch 2/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.4555 - accuracy: 0.7983 - val_loss: 0.4552 - val_accuracy: 0.7930
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4374 - accuracy: 0.8026 - val_loss: 0.4446 - val_accuracy: 0.7950
# Epoch 4/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4278 - accuracy: 0.8061 - val_loss: 0.4354 - val_accuracy: 0.7980
# Epoch 5/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.4194 - accuracy: 0.8084 - val_loss: 0.4273 - val_accuracy: 0.8030
# Epoch 6/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4106 - accuracy: 0.8131 - val_loss: 0.4181 - val_accuracy: 0.8060
# Epoch 7/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4010 - accuracy: 0.8190 - val_loss: 0.4087 - val_accuracy: 0.8210
# Epoch 8/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3900 - accuracy: 0.8284 - val_loss: 0.3974 - val_accuracy: 0.8300
# Epoch 9/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3788 - accuracy: 0.8367 - val_loss: 0.3860 - val_accuracy: 0.8350
# Epoch 10/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3677 - accuracy: 0.8457 - val_loss: 0.3768 - val_accuracy: 0.8415
# Epoch 11/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3585 - accuracy: 0.8472 - val_loss: 0.3680 - val_accuracy: 0.8470
# Epoch 12/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3521 - accuracy: 0.8536 - val_loss: 0.3631 - val_accuracy: 0.8515
# Epoch 13/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3480 - accuracy: 0.8569 - val_loss: 0.3612 - val_accuracy: 0.8500
# Epoch 14/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3448 - accuracy: 0.8587 - val_loss: 0.3587 - val_accuracy: 0.8545
# Epoch 15/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3431 - accuracy: 0.8609 - val_loss: 0.3558 - val_accuracy: 0.8595
# Epoch 16/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3405 - accuracy: 0.8612 - val_loss: 0.3559 - val_accuracy: 0.8610
# Epoch 17/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3393 - accuracy: 0.8612 - val_loss: 0.3550 - val_accuracy: 0.8575
# Epoch 18/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3376 - accuracy: 0.8614 - val_loss: 0.3545 - val_accuracy: 0.8560
# Epoch 19/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3369 - accuracy: 0.8618 - val_loss: 0.3528 - val_accuracy: 0.8580
# Epoch 20/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3358 - accuracy: 0.8610 - val_loss: 0.3523 - val_accuracy: 0.8595
# Epoch 21/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3346 - accuracy: 0.8615 - val_loss: 0.3510 - val_accuracy: 0.8610
# Epoch 22/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3338 - accuracy: 0.8629 - val_loss: 0.3516 - val_accuracy: 0.8620
# Epoch 23/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3333 - accuracy: 0.8630 - val_loss: 0.3513 - val_accuracy: 0.8610
# Epoch 24/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3325 - accuracy: 0.8625 - val_loss: 0.3506 - val_accuracy: 0.8610
# Epoch 25/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3321 - accuracy: 0.8626 - val_loss: 0.3548 - val_accuracy: 0.8565
# Epoch 26/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3309 - accuracy: 0.8630 - val_loss: 0.3526 - val_accuracy: 0.8570
# Epoch 27/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3309 - accuracy: 0.8626 - val_loss: 0.3495 - val_accuracy: 0.8625
# Epoch 28/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3300 - accuracy: 0.8636 - val_loss: 0.3502 - val_accuracy: 0.8600
# Epoch 29/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3300 - accuracy: 0.8649 - val_loss: 0.3501 - val_accuracy: 0.8595
# Epoch 30/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.8627 - val_loss: 0.3500 - val_accuracy: 0.8590
# Epoch 31/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8639 - val_loss: 0.3479 - val_accuracy: 0.8590
# Epoch 32/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3287 - accuracy: 0.8626 - val_loss: 0.3480 - val_accuracy: 0.8590
# Epoch 33/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8635 - val_loss: 0.3486 - val_accuracy: 0.8580
# Epoch 34/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3277 - accuracy: 0.8644 - val_loss: 0.3486 - val_accuracy: 0.8585
# Epoch 35/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3275 - accuracy: 0.8641 - val_loss: 0.3470 - val_accuracy: 0.8595
# Epoch 36/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3266 - accuracy: 0.8658 - val_loss: 0.3479 - val_accuracy: 0.8600
# Epoch 37/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3267 - accuracy: 0.8639 - val_loss: 0.3484 - val_accuracy: 0.8590
# Epoch 38/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8650 - val_loss: 0.3479 - val_accuracy: 0.8575
# Epoch 39/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3259 - accuracy: 0.8639 - val_loss: 0.3472 - val_accuracy: 0.8545
# Epoch 40/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3256 - accuracy: 0.8650 - val_loss: 0.3492 - val_accuracy: 0.8630
# Epoch 41/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3252 - accuracy: 0.8644 - val_loss: 0.3465 - val_accuracy: 0.8600
# Epoch 42/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3250 - accuracy: 0.8656 - val_loss: 0.3483 - val_accuracy: 0.8590
# Epoch 43/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3244 - accuracy: 0.8648 - val_loss: 0.3470 - val_accuracy: 0.8565
# Epoch 44/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3244 - accuracy: 0.8625 - val_loss: 0.3474 - val_accuracy: 0.8545
# Epoch 45/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3240 - accuracy: 0.8675 - val_loss: 0.3467 - val_accuracy: 0.8585
# Epoch 46/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3236 - accuracy: 0.8664 - val_loss: 0.3466 - val_accuracy: 0.8565
# Epoch 47/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3239 - accuracy: 0.8636 - val_loss: 0.3492 - val_accuracy: 0.8610
# Epoch 48/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8660 - val_loss: 0.3464 - val_accuracy: 0.8590
# Epoch 49/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3224 - accuracy: 0.8665 - val_loss: 0.3480 - val_accuracy: 0.8580
# Epoch 50/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3227 - accuracy: 0.8668 - val_loss: 0.3470 - val_accuracy: 0.8560
# Epoch 51/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3222 - accuracy: 0.8641 - val_loss: 0.3465 - val_accuracy: 0.8570
# Epoch 52/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3225 - accuracy: 0.8656 - val_loss: 0.3469 - val_accuracy: 0.8565
# Epoch 53/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3224 - accuracy: 0.8656 - val_loss: 0.3470 - val_accuracy: 0.8585
# Epoch 54/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3212 - accuracy: 0.8661 - val_loss: 0.3503 - val_accuracy: 0.8570
# Epoch 55/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8671 - val_loss: 0.3468 - val_accuracy: 0.8550
# Epoch 56/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.8655 - val_loss: 0.3483 - val_accuracy: 0.8610
# Epoch 57/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3205 - accuracy: 0.8670 - val_loss: 0.3483 - val_accuracy: 0.8605
# Epoch 58/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3208 - accuracy: 0.8661 - val_loss: 0.3467 - val_accuracy: 0.8580
# Epoch 59/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3206 - accuracy: 0.8662 - val_loss: 0.3486 - val_accuracy: 0.8595
# Epoch 60/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.8656 - val_loss: 0.3463 - val_accuracy: 0.8580
# Epoch 61/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3207 - accuracy: 0.8670 - val_loss: 0.3476 - val_accuracy: 0.8600
# Epoch 62/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3199 - accuracy: 0.8674 - val_loss: 0.3507 - val_accuracy: 0.8575
# Epoch 63/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3199 - accuracy: 0.8666 - val_loss: 0.3488 - val_accuracy: 0.8585
# Epoch 64/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8679 - val_loss: 0.3478 - val_accuracy: 0.8565
# Epoch 65/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3194 - accuracy: 0.8677 - val_loss: 0.3478 - val_accuracy: 0.8575
# Epoch 66/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3191 - accuracy: 0.8675 - val_loss: 0.3488 - val_accuracy: 0.8575
# Epoch 67/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3192 - accuracy: 0.8673 - val_loss: 0.3475 - val_accuracy: 0.8565
# Epoch 68/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3186 - accuracy: 0.8677 - val_loss: 0.3493 - val_accuracy: 0.8560
# Epoch 69/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3188 - accuracy: 0.8686 - val_loss: 0.3494 - val_accuracy: 0.8540
# Epoch 70/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3186 - accuracy: 0.8680 - val_loss: 0.3469 - val_accuracy: 0.8580
# Epoch 71/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.8673 - val_loss: 0.3463 - val_accuracy: 0.8570
# Epoch 72/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8698 - val_loss: 0.3498 - val_accuracy: 0.8560
# Epoch 73/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8677 - val_loss: 0.3482 - val_accuracy: 0.8540
# Epoch 74/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3178 - accuracy: 0.8675 - val_loss: 0.3480 - val_accuracy: 0.8595
# Epoch 75/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3178 - accuracy: 0.8677 - val_loss: 0.3473 - val_accuracy: 0.8570
# Epoch 76/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3171 - accuracy: 0.8681 - val_loss: 0.3495 - val_accuracy: 0.8580
# Epoch 77/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3169 - accuracy: 0.8691 - val_loss: 0.3481 - val_accuracy: 0.8575
# Epoch 78/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3165 - accuracy: 0.8692 - val_loss: 0.3490 - val_accuracy: 0.8590
# Epoch 79/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3166 - accuracy: 0.8680 - val_loss: 0.3473 - val_accuracy: 0.8595
# Epoch 80/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3163 - accuracy: 0.8687 - val_loss: 0.3477 - val_accuracy: 0.8575
# Epoch 81/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3167 - accuracy: 0.8679 - val_loss: 0.3479 - val_accuracy: 0.8595
# Epoch 82/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3163 - accuracy: 0.8700 - val_loss: 0.3478 - val_accuracy: 0.8555
# Epoch 83/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3160 - accuracy: 0.8681 - val_loss: 0.3468 - val_accuracy: 0.8615
# Epoch 84/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3165 - accuracy: 0.8685 - val_loss: 0.3492 - val_accuracy: 0.8570
# Epoch 85/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3161 - accuracy: 0.8681 - val_loss: 0.3472 - val_accuracy: 0.8550
# Epoch 86/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3161 - accuracy: 0.8694 - val_loss: 0.3510 - val_accuracy: 0.8600
# Epoch 87/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3156 - accuracy: 0.8680 - val_loss: 0.3461 - val_accuracy: 0.8625
# Epoch 88/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3158 - accuracy: 0.8683 - val_loss: 0.3461 - val_accuracy: 0.8610
# Epoch 89/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3152 - accuracy: 0.8689 - val_loss: 0.3491 - val_accuracy: 0.8565
# Epoch 90/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3154 - accuracy: 0.8680 - val_loss: 0.3483 - val_accuracy: 0.8585
# Epoch 91/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3152 - accuracy: 0.8689 - val_loss: 0.3478 - val_accuracy: 0.8580
# Epoch 92/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3149 - accuracy: 0.8679 - val_loss: 0.3475 - val_accuracy: 0.8595
# Epoch 93/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3149 - accuracy: 0.8698 - val_loss: 0.3464 - val_accuracy: 0.8580
# Epoch 94/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3143 - accuracy: 0.8704 - val_loss: 0.3497 - val_accuracy: 0.8640
# Epoch 95/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3148 - accuracy: 0.8694 - val_loss: 0.3473 - val_accuracy: 0.8605
# Epoch 96/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3148 - accuracy: 0.8698 - val_loss: 0.3474 - val_accuracy: 0.8590
# Epoch 97/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3142 - accuracy: 0.8700 - val_loss: 0.3467 - val_accuracy: 0.8605
# Epoch 98/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.8689 - val_loss: 0.3476 - val_accuracy: 0.8605
# Epoch 99/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3147 - accuracy: 0.8695 - val_loss: 0.3470 - val_accuracy: 0.8610
# Epoch 100/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3144 - accuracy: 0.8691 - val_loss: 0.3478 - val_accuracy: 0.8570

# %%
history.history

# %%
# 这段代码参考《Python深度学习》一书中的学习曲线的实现
def show_history(history): # 显示训练过程中的学习曲线
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.figure(figsize=(12,4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
show_history(history) # 调用这个函数，并将神经网络训练历史数据作为参数输入

# %%
y_pred = model.predict(X_test,batch_size=10) # 预测测试集的标签
# Out:
# 200/200 [==============================] - 0s 2ms/step

# %%
y_pred = np.round(y_pred) # 四舍五入，将分类概率值转换成0/1整数值

# %%
y_pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %%
from sklearn.metrics import classification_report # 导入分类报告
def show_report(X_test, y_test, y_pred): # 定义一个函数显示分类报告
    if y_test.shape != (2000,1):
        y_test = y_test.values # 把Panda series转换成Numpy array
        y_test = y_test.reshape((len(y_test),1)) # 转换成与y_pred相同的形状
    print(classification_report(y_test,y_pred,labels=[0, 1])) #调用分类报告

# %%
show_report(X_test, y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.91      1583
#            1       0.74      0.48      0.59       417
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
