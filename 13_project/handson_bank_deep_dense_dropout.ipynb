# %%
"""
银行客户流失分类问题：
标签分类不平衡
深层全连接网络
"""
import numpy as np  # 导入NumPy数学工具箱
import pandas as pd  # 导入Pandas数据处理工具箱
import matplotlib.pyplot as plt  # 导入matplotlib画图工具箱
import seaborn as sns  # 导入seaborn画图工具箱
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.preprocessing import StandardScaler  # 导入特征缩放器
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

# %%
# %load_ext tensorboard

# %%
df_bank = pd.read_csv('/content/drive/MyDrive/DL/data_test/handson_book/BankCustomer.csv')
df_bank.head()
# Out:
#               Name  Gender  Age     City  Tenure  ProductsNo  HasCard  \
# 0         Kan Jian  Female   40  Beijing       9           2        0
# 1      Xue Baochai    Male   69  Beijing       6           2        0
# 2           Mao Xi  Female   32  Beijing       9           1        1
# 3  Zheng Nengliang  Female   37  Tianjin       0           2        1
# 4          Zhi Fen    Male   55  Tianjin       4           3        1
#
#    ActiveMember  Credit  AccountBal       Salary  Exited
# 0             1     516     6360.66       0.0000       0
# 1             1     682    28605.00       0.0000       0
# 2             1     803    10378.09  236311.0932       1
# 3             1     778    25564.01  129909.8079       1
# 4             0     547     3235.61  136976.1948       1

# %%
# 显示不同特征的分布情况
features = ['City', 'Gender', 'Age', 'Tenure',
            'ProductsNo', 'HasCard', 'ActiveMember', 'Exited']

# %%
# --------------------------数据预处理--------------------------#
# 把二元类别文本数字化
df_bank['Gender'].replace("Female", 0, inplace=True)
df_bank['Gender'].replace("Male", 1, inplace=True)
print("Gender unique values", df_bank['Gender'].unique())  # Gender unique values [0 1]
# Out:
# Gender unique values [0 1]

# %%
# 把多元类别转换成多个二元哑变量，然后贴回原始数据集
d_city = pd.get_dummies(df_bank['City'], prefix="City")
df_bank = [df_bank, d_city]
df_bank = pd.concat(df_bank, axis=1)

# %%
y = df_bank['Exited']
X = df_bank.drop(['Name', 'Exited', 'City'], axis=1)
X.head()
# Out:
#    Gender  Age  Tenure  ProductsNo  HasCard  ActiveMember  Credit  AccountBal  \
# 0       0   40       9           2        0             1     516     6360.66
# 1       1   69       6           2        0             1     682    28605.00
# 2       0   32       9           1        1             1     803    10378.09
# 3       0   37       0           2        1             1     778    25564.01
# 4       1   55       4           3        1             0     547     3235.61
#
#         Salary  City_Beijing  City_Shanghai  City_Tianjin
# 0       0.0000             1              0             0
# 1       0.0000             1              0             0
# 2  236311.0932             1              0             0
# 3  129909.8079             0              0             1
# 4  136976.1948             0              0             1

# %%
# --------------------------拆分数据集--------------------------#
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2, random_state=0)

# %%
# --------------------------特征缩放--------------------------#
sc = StandardScaler()  # 特征缩放器
X_train = sc.fit_transform(X_train)  # 拟合并应用于训练集
X_test = sc.transform(X_test)  # 训练集结果应用于测试集

# %%
# 构建模型
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=12, activation='relu'),  # 输入层
    tf.keras.layers.Dense(units=24, activation='relu'),  # 隐层
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=48, activation='relu'),  # 隐层
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=96, activation='relu'),  # 隐层
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=192, activation='relu'),  # 隐层
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=1, activation='sigmoid')  # 输出层，二分类
])

# %%
# 编译模型
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, min_lr=1e-7)
model_ckpt = ModelCheckpoint(filepath='./ckpt/model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='max')
tensorboard_callback = TensorBoard("logs")
callbacks = [early_stop, reduce_lr, model_ckpt, tensorboard_callback]  # 设定回调

# %%
history = model.fit(X_train, y_train, # 指定训练集
                  epochs=100,        # 指定训练的轮次
                  batch_size=64,    # 指定数据批量
                  validation_data=(X_test, y_test),  #指定验证集,这里为了简化模型，直接用测试集数据进行验证
                  callbacks = callbacks)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5818: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 118/125 [===========================>..] - ETA: 0s - loss: 0.5474 - accuracy: 0.7824
# Epoch 1: val_loss improved from -inf to 0.51583, saving model to ./ckpt/model.h5
# 125/125 [==============================] - 6s 9ms/step - loss: 0.5476 - accuracy: 0.7824 - val_loss: 0.5158 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 2/100
#  26/125 [=====>........................] - ETA: 0s - loss: 0.5169 - accuracy: 0.7861
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 117/125 [===========================>..] - ETA: 0s - loss: 0.4971 - accuracy: 0.7987
# Epoch 2: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4987 - accuracy: 0.7976 - val_loss: 0.5132 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 3/100
# 117/125 [===========================>..] - ETA: 0s - loss: 0.4866 - accuracy: 0.7962
# Epoch 3: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4837 - accuracy: 0.7975 - val_loss: 0.4917 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 4/100
# 124/125 [============================>.] - ETA: 0s - loss: 0.4701 - accuracy: 0.7975
# Epoch 4: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 7ms/step - loss: 0.4700 - accuracy: 0.7975 - val_loss: 0.4878 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 5/100
# 122/125 [============================>.] - ETA: 0s - loss: 0.4585 - accuracy: 0.7989
# Epoch 5: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4610 - accuracy: 0.7975 - val_loss: 0.4901 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 6/100
# 124/125 [============================>.] - ETA: 0s - loss: 0.4531 - accuracy: 0.7969
# Epoch 6: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 8ms/step - loss: 0.4526 - accuracy: 0.7975 - val_loss: 0.5040 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 7/100
# 123/125 [============================>.] - ETA: 0s - loss: 0.4501 - accuracy: 0.7961
# Epoch 7: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4487 - accuracy: 0.7975 - val_loss: 0.4916 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 8/100
# 118/125 [===========================>..] - ETA: 0s - loss: 0.4489 - accuracy: 0.7970
# Epoch 8: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4477 - accuracy: 0.7975 - val_loss: 0.5074 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 9/100
# 124/125 [============================>.] - ETA: 0s - loss: 0.4372 - accuracy: 0.7976
# Epoch 9: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4379 - accuracy: 0.7975 - val_loss: 0.4919 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 10/100
# 122/125 [============================>.] - ETA: 0s - loss: 0.4435 - accuracy: 0.7967
# Epoch 10: val_loss did not improve from 0.51583
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4424 - accuracy: 0.7975 - val_loss: 0.5086 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 11/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.7975
# Epoch 11: val_loss did not improve from 0.51583
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4361 - accuracy: 0.7975 - val_loss: 0.5088 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 12/100
# 117/125 [===========================>..] - ETA: 0s - loss: 0.4314 - accuracy: 0.7971
# Epoch 12: val_loss did not improve from 0.51583
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4323 - accuracy: 0.7975 - val_loss: 0.5128 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 13/100
# 119/125 [===========================>..] - ETA: 0s - loss: 0.4330 - accuracy: 0.7965
# Epoch 13: val_loss improved from 0.51583 to 0.52107, saving model to ./ckpt/model.h5
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4304 - accuracy: 0.7975 - val_loss: 0.5211 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 14/100
# 121/125 [============================>.] - ETA: 0s - loss: 0.4281 - accuracy: 0.8051
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 14: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4266 - accuracy: 0.8060 - val_loss: 0.4962 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 15/100
# 120/125 [===========================>..] - ETA: 0s - loss: 0.4264 - accuracy: 0.8060
# Epoch 15: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4248 - accuracy: 0.8065 - val_loss: 0.5005 - val_accuracy: 0.8205 - lr: 1.0000e-04
# Epoch 16/100
# 121/125 [============================>.] - ETA: 0s - loss: 0.4219 - accuracy: 0.8075
# Epoch 16: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4234 - accuracy: 0.8069 - val_loss: 0.5033 - val_accuracy: 0.8215 - lr: 1.0000e-04
# Epoch 17/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8075
# Epoch 17: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4207 - accuracy: 0.8075 - val_loss: 0.5037 - val_accuracy: 0.8210 - lr: 1.0000e-04
# Epoch 18/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8086
# Epoch 18: val_loss did not improve from 0.52107
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4217 - accuracy: 0.8086 - val_loss: 0.5044 - val_accuracy: 0.8240 - lr: 1.0000e-04
# Epoch 19/100
# 124/125 [============================>.] - ETA: 0s - loss: 0.4217 - accuracy: 0.8051
# Epoch 19: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4220 - accuracy: 0.8049 - val_loss: 0.5028 - val_accuracy: 0.8235 - lr: 1.0000e-04
# Epoch 20/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4257 - accuracy: 0.8065
# Epoch 20: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4257 - accuracy: 0.8065 - val_loss: 0.5070 - val_accuracy: 0.8250 - lr: 1.0000e-04
# Epoch 21/100
# 123/125 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8041
# Epoch 21: val_loss did not improve from 0.52107
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4227 - accuracy: 0.8049 - val_loss: 0.5085 - val_accuracy: 0.8260 - lr: 1.0000e-04
# Epoch 22/100
# 122/125 [============================>.] - ETA: 0s - loss: 0.4234 - accuracy: 0.8089
# Epoch 22: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4222 - accuracy: 0.8100 - val_loss: 0.5070 - val_accuracy: 0.8260 - lr: 1.0000e-04
# Epoch 23/100
# 122/125 [============================>.] - ETA: 0s - loss: 0.4251 - accuracy: 0.8108
# Epoch 23: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4258 - accuracy: 0.8099 - val_loss: 0.5068 - val_accuracy: 0.8255 - lr: 1.0000e-04
# Epoch 24/100
# 122/125 [============================>.] - ETA: 0s - loss: 0.4192 - accuracy: 0.8137Restoring model weights from the end of the best epoch: 4.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 24: val_loss did not improve from 0.52107
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4210 - accuracy: 0.8129 - val_loss: 0.5074 - val_accuracy: 0.8260 - lr: 1.0000e-04
# Epoch 24: early stopping

# %%
def show_history(history):  # 显示训练过程中的学习曲线
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()


show_history(history)  # 调用这个函数，并将神经网络训练历史数据作为参数输入

# %%
# 预测
y_pred = model.predict(X_test, batch_size=10)  # 预测测试集的标签
y_pred = np.round(y_pred)  # 四舍五入，将分类概率值转换成0/1整数值
# Out:
# 200/200 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import classification_report
def show_report(X_test, y_test, y_pred):  # 定义一个函数显示分类报告
    if y_test.shape != (2000, 1):
        y_test = y_test.values  # 把Panda series转换成Numpy array
        y_test = y_test.reshape((len(y_test), 1))  # 转换成与y_pred相同的形状
    print(classification_report(y_test, y_pred, labels=[0, 1]))  # 调用分类报告

# %%
show_report(X_test, y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1583
#            1       0.00      0.00      0.00       417
#
#     accuracy                           0.79      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.63      0.79      0.70      2000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
